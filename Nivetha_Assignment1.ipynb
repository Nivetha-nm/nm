# %%
#VISUALISATION
  #1)UNIVARIATE

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df['Price']
# Out:
# 0        2380000
# 1        1400000
# 2        1200000
# 3         838000
# 4         805000
#           ...
# 14615     221700
# 14616     219200
# 14617     209000
# 14618     205000
# 14619     146000
# Name: Price, Length: 14620, dtype: int64

# %%
sns.countplot(df['Price'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Built Year']
# Out:
# 0        1921
# 1        1909
# 2        1939
# 3        2001
# 4        1929
#          ...
# 14615    1957
# 14616    1968
# 14617    1962
# 14618    1955
# 14619    1969
# Name: Built Year, Length: 14620, dtype: int64

# %%
sns.countplot(df['Built Year'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data=df,x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.boxplot(df['Built Year'])
# Out:
# <Axes: >

# %%
#Bivariate Analysis

# %%
sns.countplot(data=df,x='Price',hue='Number of schools nearby')
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.scatterplot(data=df,x='Built Year',y='Price')
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
#Multivariate

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
#Descriptive statistics

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.describe(include='all')
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
#DATA WRANGLING

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df['Price'].mean()
# Out:
# 538932.2183310534

# %%
df['Built Year'].median()
# Out:
# 1975.0

# %%
df['Price'] = df['Price'].fillna(df['Price'].mean())
df['Built Year'] = df['Built Year'].fillna(df['Built Year'].median())

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df['Built Year']>1967
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 14615    False
# 14616     True
# 14617    False
# 14618    False
# 14619     True
# Name: Built Year, Length: 14620, dtype: bool

# %%
df[df['Built Year']>1940]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 3      6762812605  42491                   4                 2.50
# 5      6762813105  42491                   3                 2.50
# 6      6762813157  42491                   5                 3.25
# 8      6762813600  42491                   3                 2.50
# 10     6762814787  42491                   5                 2.50
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 3             3310     42998               2.0                   0
# ...

# %%
df[df['Price']>=100000]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df['Postal Code']==122004
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 14615    False
# 14616    False
# 14617    False
# 14618    False
# 14619    False
# Name: Postal Code, Length: 14620, dtype: bool

# %%
df[df['Postal Code']==122004]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 78     6762810636  42494                   5                 3.50
# 99     6762814896  42494                   3                 2.50
# 162    6762810471  42495                   4                 3.25
# ...           ...    ...                 ...                  ...
# 14276  6762814914  42725                   3                 1.00
# 14287  6762817093  42725                   3                 1.75
# 14289  6762817668  42725                   4                 2.00
# 14338  6762811170  42726                   4                 3.00
# 14481  6762815079  42732                  10                 3.00
#
#        living area  lot area  number of floors  waterfront present  \
# 1             2920      4000               1.5                   0
# ...

# %%
[df['Postal Code']==122004] or [df['Price']>100000]
# Out:
# [0        False
#  1         True
#  2         True
#  3        False
#  4        False
#           ...
#  14615    False
#  14616    False
#  14617    False
#  14618    False
#  14619    False
#  Name: Postal Code, Length: 14620, dtype: bool]

# %%
df[(df['Postal Code']==122004) & (df['Price']>100000)]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 78     6762810636  42494                   5                 3.50
# 99     6762814896  42494                   3                 2.50
# 162    6762810471  42495                   4                 3.25
# ...           ...    ...                 ...                  ...
# 14276  6762814914  42725                   3                 1.00
# 14287  6762817093  42725                   3                 1.75
# 14289  6762817668  42725                   4                 2.00
# 14338  6762811170  42726                   4                 3.00
# 14481  6762815079  42732                  10                 3.00
#
#        living area  lot area  number of floors  waterfront present  \
# 1             2920      4000               1.5                   0
# ...

# %%
df[(df['Price']>100000)& (df['Postal Code']==122004)]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 78     6762810636  42494                   5                 3.50
# 99     6762814896  42494                   3                 2.50
# 162    6762810471  42495                   4                 3.25
# ...           ...    ...                 ...                  ...
# 14276  6762814914  42725                   3                 1.00
# 14287  6762817093  42725                   3                 1.75
# 14289  6762817668  42725                   4                 2.00
# 14338  6762811170  42726                   4                 3.00
# 14481  6762815079  42732                  10                 3.00
#
#        living area  lot area  number of floors  waterfront present  \
# 1             2920      4000               1.5                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...
